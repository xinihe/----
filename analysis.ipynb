# %%
import pandas as pd
#pd.set_option('display.max_rows', None)

# %%
df0 = pd.read_excel('2020general.xls', index_col=0)
df1 = pd.read_excel('2021general.xls', index_col=0)
df2 = pd.read_excel('2022general.xls', index_col=0)
df_gen = pd.concat([df0,df1,df2])[['课题名称','姓名','工作单位','所在省市','项目类别','所在学科']]
df_gen.head()
# Out:
#                              课题名称   姓名      工作单位 所在省市  项目类别   所在学科
# 序号
# 1                   马克思早期代表性论著新探讨   林锋      北京大学   高校  重点项目  马列·科社
# 2                      中国《资本论》研究史  刘新刚    北京理工大学   高校  重点项目  马列·科社
# 3           2020年后农村减贫与乡村振兴协同推进研究  吴晓燕  中共四川省委党校   四川  重点项目  马列·科社
# 4           十月革命后列宁社会主义社会观的前进轨迹研究   俞敏    南京师范大学   江苏  重点项目  马列·科社
# 5   唯物史观视域中人类命运共同体思想的原创性贡献与世界意义研究  李包庚      宁波大学   浙江  重点项目  马列·科社

# %%
df0 = pd.read_excel('2020general.xls', index_col=0)
df1 = pd.read_excel('2021general.xls', index_col=0)
df2 = pd.read_excel('2022general.xls', index_col=0)
df_you = pd.concat([df0,df1,df2])[['课题名称','姓名','工作单位','所在省市','项目类别','所在学科']]
df_you.head()
# Out:
# 10633

# %%
name_text = df[(df['所在学科']=='应用经济')& (df['项目类别']=='一般项目')]['课题名称'].reset_index().drop('序号', axis=1)

# %%
name_text[name_text['课题名称'].str.contains('普惠')]
# Out:
#                                课题名称
# 39         我国农村普惠金融协同供给、异质需求与长效机制研究
# 40  数字普惠金融背景下我国农村金融消费者保护测度、影响及其提升研究
# 41        城乡融合背景下普惠金融缓解相对贫困的机制与路径研究
# 42        普惠金融支持农业创新链和产业链对接的机制与路径研究
# 43       西部民族地区普惠金融影响经济高质量发展的空间效应研究
# 44        机会平等视角下普惠金融发展的目标偏离与矫正机制研究
# 45   数字普惠金融支持中小企业发展效率提升的机理分析与优化路径研究

# %% [markdown]
# 数字普惠金融 风险测度 信贷可得性 中小微企业增信 金融韧性
#
# 金融健康是普惠金融发展的高级形态

# %%
df[df['课题名称'].str.contains('普惠')]
# Out:
#                                 课题名称   姓名      工作单位 所在省市  项目类别        预期成果  \
# 序号
# 793         数字普惠金融促进乡村产业振兴的模式创新与政策研究  葛和平  南京信息工程大学   江苏  一般项目  论文集  研究报告
# 832           “新基建”背景下中国农村普惠金融发展对策研究  郑海荣    福建农林大学   福建  一般项目       研究报告
# 833   不确定性视角下农村普惠金融创新发展减缓相对贫困的长效机制研究   张琦    湖南工商大学   湖南  一般项目       研究报告
# 834         城乡融合背景下支持农民转型发展的普惠金融对策研究  傅巧灵    北京联合大学   北京  一般项目  论文集  研究报告
# 837         农村普惠金融市场竞争风险的生成机制与防范对策研究  陆智强      宁波大学   浙江  一般项目       研究报告
# 847          数字普惠金融背景下贫困农户金融能力提升路径研究   刘勇    武汉科技大学   湖北  一般项目  论文集  研究报告
# 853     信息沟壑约束下数字普惠金融缓解农村相对贫困的长尾效应研究  谢升峰      湖北大学   湖北  一般项目  论文集  研究报告
# 928        科技赋能背景下普惠金融的实体经济效应及优化发展研究   丁杰    广东财经大学   广东  一般项目       论文集
# 935         推动中国实体经济高质量发展的普惠金融发展对策研究  钱明辉    东北财经大学   辽宁  一般项目       研究报告
# 940             风险测度、农户增信与农村普惠金融优化研究  叶明华    华东师范大学   上海  一般项目    专著 论文集
# 1610        普惠性托育机构试点效果跟踪评估与长效机制构建研究  周冬霞  中南财经政法大学   湖北  一般项目    专著 研究报告
#
#          计划完成时间  所在学科       批准号
# 序号
# 793  2023-06-30  应用经济  20BJY114
# 832  2023-07-31  应用经济  20BJY153
# 833  2023-12-31  应用经济  20BJY154
# 834  2023-06-30  应用经济  20BJY155
# 837  2023-06-30  应用经济  20BJY158
# 847  2023-12-31  应用经济  20BJY168
# 853  2023-03-30  应用经济  20BJY174
# 928  2023-06-30  应用经济  20BJY249
# 935  2023-06-30  应用经济  20BJY256
# 940  2023-12-31  应用经济  20BJY261
# 1610 2023-06-30   人口学  20BRK046

# %%
len(df[df['课题名称'].str.contains('普惠')])
# Out:
# 11

# %%
df[df['课题名称'].str.contains('普惠')]
# Out:
#                              课题名称   姓名      工作单位 所在省市  项目类别      预期成果  \
# 序号
# 561     数字普惠金融引致系统性金融风险的演化机制与防范研究  谢俊明      湘南学院  湖南省  一般项目  论文集,研究报告
# 691      数字普惠金融赋能乡村振兴的模式创新与政策优化研究   柳松    华南农业大学  广东省  一般项目      研究报告
# 692    数字普惠金融促进新型农业经营主体发展的机理与政策研究   杨岸  湖南财政经济学院  湖南省  一般项目      研究报告
# 693             农村普惠金融质量测度与提升对策研究  丁淑娟    山东师范大学  山东省  一般项目      研究报告
# 762   数字普惠金融支持中小企业信用共同体融资的机制与对策研究  徐小阳      江苏大学  江苏省  一般项目      研究报告
# 1292              数字普惠金融激励性监管制度研究   孟飞  上海工程技术大学  上海市  一般项目        专著
# 1468          新型产业工人子女普惠托育服务同城化研究  于冬青    东北师范大学  吉林省  一般项目  论文集,研究报告
# 1485  新发展阶段脱贫地区农村幼儿教育普惠优质发展机制构建研究   李静      西南大学  重庆市  一般项目  论文集,研究报告
# 1519  普惠养老视域下超大城市社区居家养老服务整合模式创新研究  孟荣芳  中共南京市委党校  江苏省  一般项目  论文集,研究报告
#
#         计划完成\n时间  所在学科       批准号
# 序号
# 561   2024-06-30  理论经济  22BJL041
# 691   2025-06-30  应用经济  22BJY005
# 692   2025-12-30  应用经济  22BJY006
# 693   2025-06-30  应用经济  22BJY007
# 762   2025-12-31  应用经济  22BJY076
# 1292  2025-06-30    法学  22BFX112
# 1468  2025-02-28   社会学  22BSH060
# 1485  2025-12-31   社会学  22BSH077
# 1519  2024-12-31   社会学  22BSH111

# %%
df[df['课题名称'].str.contains('普惠')]
# Out:
#                                 课题名称   姓名      工作单位 所在省市  项目类别        预期成果  \
# 序号
# 793         数字普惠金融促进乡村产业振兴的模式创新与政策研究  葛和平  南京信息工程大学   江苏  一般项目  论文集  研究报告
# 832           “新基建”背景下中国农村普惠金融发展对策研究  郑海荣    福建农林大学   福建  一般项目       研究报告
# 833   不确定性视角下农村普惠金融创新发展减缓相对贫困的长效机制研究   张琦    湖南工商大学   湖南  一般项目       研究报告
# 834         城乡融合背景下支持农民转型发展的普惠金融对策研究  傅巧灵    北京联合大学   北京  一般项目  论文集  研究报告
# 837         农村普惠金融市场竞争风险的生成机制与防范对策研究  陆智强      宁波大学   浙江  一般项目       研究报告
# 847          数字普惠金融背景下贫困农户金融能力提升路径研究   刘勇    武汉科技大学   湖北  一般项目  论文集  研究报告
# 853     信息沟壑约束下数字普惠金融缓解农村相对贫困的长尾效应研究  谢升峰      湖北大学   湖北  一般项目  论文集  研究报告
# 928        科技赋能背景下普惠金融的实体经济效应及优化发展研究   丁杰    广东财经大学   广东  一般项目       论文集
# 935         推动中国实体经济高质量发展的普惠金融发展对策研究  钱明辉    东北财经大学   辽宁  一般项目       研究报告
# 940             风险测度、农户增信与农村普惠金融优化研究  叶明华    华东师范大学   上海  一般项目    专著 论文集
# 1610        普惠性托育机构试点效果跟踪评估与长效机制构建研究  周冬霞  中南财经政法大学   湖北  一般项目    专著 研究报告
#
#          计划完成时间  所在学科       批准号
# 序号
# 793  2023-06-30  应用经济  20BJY114
# 832  2023-07-31  应用经济  20BJY153
# 833  2023-12-31  应用经济  20BJY154
# 834  2023-06-30  应用经济  20BJY155
# 837  2023-06-30  应用经济  20BJY158
# 847  2023-12-31  应用经济  20BJY168
# 853  2023-03-30  应用经济  20BJY174
# 928  2023-06-30  应用经济  20BJY249
# 935  2023-06-30  应用经济  20BJY256
# 940  2023-12-31  应用经济  20BJY261
# 1610 2023-06-30   人口学  20BRK046

# %%
pip install wxpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wxpy
#   Downloading wxpy-0.3.9.8.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 673.1 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting itchat==1.2.32
#   Downloading itchat-1.2.32-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: requests in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from wxpy) (2.28.1)
# Requirement already satisfied: future in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from wxpy) (0.18.2)
# Requirement already satisfied: pyqrcode in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from itchat==1.2.32->wxpy) (1.2.1)
# Requirement already satisfied: pypng in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from itchat==1.2.32->wxpy) (0.20220715.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from requests->wxpy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from requests->wxpy) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from requests->wxpy) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nihe/Library/Python/3.9/lib/python/site-packages (from requests->wxpy) (2022.9.24)
# Building wheels for collected packages: wxpy
#   Building wheel for wxpy (setup.py) ... done
#   Created wheel for wxpy: filename=wxpy-0.3.9.8-py3-none-any.whl size=63041 sha256=caefd2ddb001465818540b00b0e2f15c65c46ac8edba6d059c53cd1d0549a4e5
#   Stored in directory: /Users/nihe/Library/Caches/pip/wheels/02/f1/d1/c7a2b401b420c6cc648ce75737cdaedb57e340859c6fb8f0cf
# Successfully built wxpy
# Installing collected packages: itchat, wxpy
#   Attempting uninstall: itchat
#     Found existing installation: itchat 1.3.10
#     Uninstalling itchat-1.3.10:
#       Successfully uninstalled itchat-1.3.10
#   WARNING: The script wxpy is installed in '/Users/nihe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed itchat-1.2.32 wxpy-0.3.9.8
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import itchat
import importlib,sys 
importlib.reload(sys)
import sys
def get_response(_info):
    print(_info)                                       # 从好友发过来的消息
    api_url = 'http://www.tuling123.com/openapi/api'   # 图灵机器人网址
    data = {
        'key': '466856743b3442bf95acb1e21a5218e2',     # 如果这个 apiKey 如不能用，那就注册一次
        'info': _info,                                 # 这是我们从好友接收到的消息 然后转发给图灵机器人
        'userid': 'wechat-robot',                      # 这里你想改什么都可以
    }
    r = requests.post(api_url, data=data).json()       # 把data数据发
    print(r.get('text'))                               # 机器人回复给好友的消息
    return r
@itchat.msg_register(itchat.content.TEXT)
def text_reply(msg):
    return "" + get_response(msg["Text"])["text"]
if __name__ == '__main__':
    itchat.auto_login()                  # hotReload = True, 保持在线，下次运行代码可自动登录  hotReload=True
    itchat.run()
# Out:
# itchat has already logged in.
# Start auto replying.

# %%
from wxpy import Bot,Tuling,embed,ensure_one
bot = Bot()
my_friend = ensure_one(bot.search('张三'))  #想和机器人聊天的好友的备注
tuling = Tuling(api_key='466856743b3442bf95acb1e21a5218e2')     #这里是图灵机器人申请后的api
@bot.register(my_friend)  # 使用图灵机器人自动与指定好友聊天
def reply_my_friend(msg):
    tuling.do_reply(msg)
embed()
# Out:
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Log in time out, reloading QR code.
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [14], line 2
#       1 from wxpy import Bot,Tuling,embed,ensure_one
# ----> 2 bot = Bot()
#       3 my_friend = ensure_one(bot.search('张三'))  #想和机器人聊天的好友的备注
#       4 tuling = Tuling(api_key='466856743b3442bf95acb1e21a5218e2')     #这里是图灵机器人申请后的api
#
# File ~/Library/Python/3.9/lib/python/site-packages/wxpy/api/bot.py:83, in Bot.__init__(self, cache_path, console_qr, qr_path, qr_callback, login_callback, logout_callback)
#      80     console_qr = 2
#      82 try:
# ---> 83     self.core.auto_login(
#      84         hotReload=bool(cache_path), statusStorageDir=cache_path,
#      85         enableCmdQR=console_qr, picDir=qr_path, qrCallback=qr_callback,
#      86         loginCallback=login_callback, exitCallback=logout_callback
#      87     )
#      88 except FileNotFoundError as e:
#      89     if 'xdg-open' in e.strerror:
#
# File ~/Library/Python/3.9/lib/python/site-packages/itchat/components/register.py:35, in auto_login(self, hotReload, statusStorageDir, enableCmdQR, picDir, qrCallback, loginCallback, exitCallback)
#      33     self.dump_login_status(statusStorageDir)
#      34 else:
# ---> 35     self.login(enableCmdQR=enableCmdQR, picDir=picDir, qrCallback=qrCallback,
#      36         loginCallback=loginCallback, exitCallback=exitCallback)
#
# File ~/Library/Python/3.9/lib/python/site-packages/itchat/components/login.py:53, in login(self, enableCmdQR, picDir, qrCallback, loginCallback, exitCallback)
#      51 isLoggedIn = False
#      52 while not isLoggedIn:
# ---> 53     status = self.check_login()
#      54     if hasattr(qrCallback, '__call__'):
#      55         qrCallback(uuid=self.uuid, status=status, qrcode=qrStorage.getvalue())
#
# File ~/Library/Python/3.9/lib/python/site-packages/itchat/components/login.py:133, in check_login(self, uuid)
#     130 params = 'loginicon=true&uuid=%s&tip=1&r=%s&_=%s' % (
#     131     uuid, int(-localTime / 1579), localTime)
#     132 headers = { 'User-Agent' : config.USER_AGENT }
# --> 133 r = self.s.get(url, params=params, headers=headers)
#     134 regx = r'window.code=(\d+)'
#     135 data = re.search(regx, r.text)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# @author S.L.

import sunCryptBasis as Crypt
import sympy
import numpy as np


class Paillier:
    def __init__(self, p=0, q=0, g=0):
        self.__p = p
        self.__q = q
        self.__n = self.__p * self.__q
        self.__lambda = sympy.lcm(self.__p - 1, self.__q - 1)

        self.__g = g
        self.__u = sympy.mod_inverse(self.__L(g**self.__lambda % self.__n**2), self.__n)
        print("p,q,n,lambda,g,u = ", self.__p, self.__q, self.__n, self.__lambda, self.__g, self.__u)

    def __L(self, x):
        return (x-1) / self.__n

    def generate_key(self, key_bits=10):
        # choose p and q, and calculate n and lambda

        while True:
            self.__p = sympy.ntheory.generate.randprime(2**key_bits, 2**(key_bits+1))
            self.__q = sympy.ntheory.generate.randprime(2**key_bits, 2**(key_bits+1))
            self.__n = self.__p * self.__q
            if sympy.gcd(self.__n, (self.__p - 1) * (self.__q - 1)) == 1:
                break
        self.__lambda = sympy.lcm(self.__p - 1, self.__q - 1)

        # choose g
        # todo
        while True:
            self.__g = np.random.randint(1, n**2)
            self.__u = sympy.mod_inverse(self.__L(g**self.__lambda % self.__n**2), self.__n)

    def encrypt(self, m, r=0):
        r = sympy.ntheory.randprime(3, self.__n) if r == 0 else r
        return self.__g ** m * r ** self.__n % (self.__n ** 2)

    def decrypt(self, c):
        return self.__L(c**self.__lambda % (self.__n**2)) * self.__u % self.__n

    def get_public_key(self):
        return self.__n, self.__g

    def get_private_key(self):
        return self.__lambda, self.__u
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 3
#       1 # @author S.L.
# ----> 3 import sunCryptBasis as Crypt
#       4 import sympy
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'sunCryptBasis'
